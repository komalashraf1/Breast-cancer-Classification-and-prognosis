# 09-Jul-2020 23:19:48 DEBUG GEOparse - SAMPLE: GSM352132
# 09-Jul-2020 23:19:49 DEBUG GEOparse - SAMPLE: GSM352133
# 09-Jul-2020 23:19:49 DEBUG GEOparse - SAMPLE: GSM352134
# 09-Jul-2020 23:19:49 DEBUG GEOparse - SAMPLE: GSM352135
# 09-Jul-2020 23:19:49 DEBUG GEOparse - SAMPLE: GSM352136
# 09-Jul-2020 23:19:49 DEBUG GEOparse - SAMPLE: GSM352137
# 09-Jul-2020 23:19:50 DEBUG GEOparse - SAMPLE: GSM352138
# 09-Jul-2020 23:19:50 DEBUG GEOparse - SAMPLE: GSM352139
# 09-Jul-2020 23:19:50 DEBUG GEOparse - SAMPLE: GSM352140
# 09-Jul-2020 23:19:50 DEBUG GEOparse - SAMPLE: GSM352141
# 09-Jul-2020 23:19:50 DEBUG GEOparse - SAMPLE: GSM352142
# 09-Jul-2020 23:19:50 DEBUG GEOparse - SAMPLE: GSM352143
# 09-Jul-2020 23:19:51 DEBUG GEOparse - SAMPLE: GSM352144
# 09-Jul-2020 23:19:51 DEBUG GEOparse - SAMPLE: GSM352145
# 09-Jul-2020 23:19:51 DEBUG GEOparse - SAMPLE: GSM352146
# 09-Jul-2020 23:19:51 DEBUG GEOparse - SAMPLE: GSM352147
# 09-Jul-2020 23:19:51 DEBUG GEOparse - SAMPLE: GSM352148
# 09-Jul-2020 23:19:51 DEBUG GEOparse - SAMPLE: GSM352149
# 09-Jul-2020 23:19:51 DEBUG GEOparse - SAMPLE: GSM352150
# 09-Jul-2020 23:19:52 DEBUG GEOparse - SAMPLE: GSM352151
# 09-Jul-2020 23:19:52 DEBUG GEOparse - SAMPLE: GSM352152
# 09-Jul-2020 23:19:52 DEBUG GEOparse - SAMPLE: GSM352153
# 09-Jul-2020 23:19:52 DEBUG GEOparse - SAMPLE: GSM352154
# 09-Jul-2020 23:19:52 DEBUG GEOparse - SAMPLE: GSM352155
# 09-Jul-2020 23:19:52 DEBUG GEOparse - SAMPLE: GSM352156
# 09-Jul-2020 23:19:52 DEBUG GEOparse - SAMPLE: GSM352157
# 09-Jul-2020 23:19:53 DEBUG GEOparse - SAMPLE: GSM352158
# 09-Jul-2020 23:19:53 DEBUG GEOparse - SAMPLE: GSM352159
# 09-Jul-2020 23:19:53 DEBUG GEOparse - SAMPLE: GSM352160
# 09-Jul-2020 23:19:53 DEBUG GEOparse - SAMPLE: GSM352161
# 09-Jul-2020 23:19:53 DEBUG GEOparse - SAMPLE: GSM352162
# 09-Jul-2020 23:19:53 DEBUG GEOparse - SAMPLE: GSM352163
# 09-Jul-2020 23:19:53 DEBUG GEOparse - SAMPLE: GSM352164
# 09-Jul-2020 23:19:54 DEBUG GEOparse - SAMPLE: GSM352165
# 09-Jul-2020 23:19:54 DEBUG GEOparse - SAMPLE: GSM352166
# 09-Jul-2020 23:19:54 DEBUG GEOparse - SAMPLE: GSM352167
# 09-Jul-2020 23:19:54 DEBUG GEOparse - SAMPLE: GSM352168

# %%
gse.gpls['GPL96'].columns
# Out:
#                                                                         description
# ID                                Affymetrix Probe Set ID LINK_PRE:"https://www....
# GB_ACC                            GenBank Accession Number LINK_PRE:"http://www....
# SPOT_ID                                                         identifies controls
# Species Scientific Name           The genus and species of the organism represen...
# Annotation Date                   The date that the annotations for this probe a...
# Sequence Type
# Sequence Source                   The database from which the sequence used to d...
# Target Description
# Representative Public ID          The accession number of a representative seque...
# Gene Title                              Title of Gene represented by the probe set.
# Gene Symbol                       A gene symbol, when one is available (from Uni...
# ENTREZ_GENE_ID                    Entrez Gene Database UID LINK_PRE:"http://www....
# RefSeq Transcript ID              References to multiple sequences in RefSeq. Th...
# Gene Ontology Biological Process  Gene Ontology Consortium Biological Process de...
# Gene Ontology Cellular Component  Gene Ontology Consortium Cellular Component de...
# Gene Ontology Molecular Function  Gene Ontology Consortium Molecular Function de...

# %%
gse.gsms["GSM352095"].table
# Out:
#                      ID_REF      VALUE
# 0                 1007_s_at  11.942972
# 1                   1053_at   9.124514
# 2                    117_at   7.832843
# 3                    121_at   9.293999
# 4                 1255_g_at   4.545640
# ...                     ...        ...
# 54670  AFFX-r2-Ec-bioC-5_at   9.612546
# 54671  AFFX-r2-Ec-bioD-3_at  12.215268
# 54672  AFFX-r2-Ec-bioD-5_at  11.681449
# 54673   AFFX-r2-P1-cre-3_at  13.761771
# 54674   AFFX-r2-P1-cre-5_at  13.626195
#
# [54675 rows x 2 columns]

# %%
#gse = GEOparse.get_GEO(geo="GSE14020", destdir="./")
print()
print("GSM example:")
for gsm_name, gsm in gse.gsms.items():
    print("Name: ", gsm_name)
    print("Metadata:",)
    for key, value in gsm.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value)))
        print ("Table data:",)
        print (gsm.table.head())
        break
print()
print("GPL example:")
for gpl_name, gpl in gse.gpls.items():
    print("Name: ", gpl_name)
    print("Metadata:",)
    for key, value in gpl.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value)))
    print("Table data:",)
    print(gpl.table.head())
    break
# Out:
# GSM example:
# Name:  GSM352095
# Metadata:
#  - title : 5381T (U133plus2): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.942972
# 1    1053_at   9.124514
# 2     117_at   7.832843
# 3     121_at   9.293999
# 4  1255_g_at   4.545640
# Name:  GSM352097
# Metadata:
#  - title : 102962T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.028198
# 1    1053_at   9.478611
# 2     117_at   8.056224
# 3     121_at   9.734242
# 4  1255_g_at   4.589639
# Name:  GSM352098
# Metadata:
#  - title : 104406T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.359949
# 1    1053_at   8.936268
# 2     117_at   8.230384
# 3     121_at   9.196800
# 4  1255_g_at   4.443698
# Name:  GSM352100
# Metadata:
#  - title : 105079T (U133plus2): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.589025
# 1    1053_at   8.035468
# 2     117_at  10.979582
# 3     121_at   9.359527
# 4  1255_g_at   4.633253
# Name:  GSM352101
# Metadata:
#  - title : 107502T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.405878
# 1    1053_at   9.168375
# 2     117_at   7.907716
# 3     121_at   9.449023
# 4  1255_g_at   4.698722
# Name:  GSM352103
# Metadata:
#  - title : 107696T (U133plus2): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.658286
# 1    1053_at   8.102512
# 2     117_at   8.983309
# 3     121_at   9.438934
# 4  1255_g_at   4.755724
# Name:  GSM352105
# Metadata:
#  - title : 107961T (U133plus2): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.835002
# 1    1053_at   9.247241
# 2     117_at   9.381022
# 3     121_at   9.383646
# 4  1255_g_at   4.530701
# Name:  GSM352107
# Metadata:
#  - title : 109506T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.091930
# 1    1053_at   9.189113
# 2     117_at   7.796607
# 3     121_at   9.080720
# 4  1255_g_at   4.644450
# Name:  GSM352109
# Metadata:
#  - title : 109594T (U133plus2): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.085872
# 1    1053_at   8.306166
# 2     117_at   8.537037
# 3     121_at   9.423481
# 4  1255_g_at   4.574697
# Name:  GSM352110
# Metadata:
#  - title : 109714T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.344569
# 1    1053_at   9.104509
# 2     117_at   7.934914
# 3     121_at   9.555070
# 4  1255_g_at   4.610129
# Name:  GSM352111
# Metadata:
#  - title : 110032T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.744260
# 1    1053_at   8.451132
# 2     117_at   7.952382
# 3     121_at   9.787788
# 4  1255_g_at   4.673303
# Name:  GSM352113
# Metadata:
#  - title : 110312T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.327385
# 1    1053_at   8.095648
# 2     117_at   8.068773
# 3     121_at   9.557379
# 4  1255_g_at   4.905926
# Name:  GSM352114
# Metadata:
#  - title : 110783T (U133plus2): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.145630
# 1    1053_at   8.129902
# 2     117_at   8.401506
# 3     121_at   9.672572
# 4  1255_g_at   4.658521
# Name:  GSM352115
# Metadata:
#  - title : 111276T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.918352
# 1    1053_at   9.083740
# 2     117_at   8.801851
# 3     121_at   9.576131
# 4  1255_g_at   4.553769
# Name:  GSM352117
# Metadata:
#  - title : 112282T (U133plus2): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.713413
# 1    1053_at   8.238892
# 2     117_at   8.646925
# 3     121_at   9.607715
# 4  1255_g_at   4.881877
# Name:  GSM352119
# Metadata:
#  - title : 112397T (U133plus2): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.703173
# 1    1053_at   7.482923
# 2     117_at   8.056855
# 3     121_at   9.444092
# 4  1255_g_at   4.596961
# Name:  GSM352120
# Metadata:
#  - title : 112403T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.452550
# 1    1053_at   8.350762
# 2     117_at   8.840931
# 3     121_at   9.544349
# 4  1255_g_at   4.571540
# Name:  GSM352121
# Metadata:
#  - title : 113471T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.282436
# 1    1053_at   8.463147
# 2     117_at   8.196595
# 3     121_at   9.667889
# 4  1255_g_at   4.767435
# Name:  GSM352122
# Metadata:
#  - title : 113542T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.339943
# 1    1053_at   8.873502
# 2     117_at   7.875237
# 3     121_at   9.351261
# 4  1255_g_at   4.603127
# Name:  GSM352123
# Metadata:
#  - title : 114112T (U133plus2): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.576822
# 1    1053_at   8.579101
# 2     117_at   8.643214
# 3     121_at   9.397724
# 4  1255_g_at   4.627876
# Name:  GSM352124
# Metadata:
#  - title : 115463T (U133plus2): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.990203
# 1    1053_at   7.875552
# 2     117_at   8.104108
# 3     121_at   9.569456
# 4  1255_g_at   4.579836
# Name:  GSM352125
# Metadata:
#  - title : 116610T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.602722
# 1    1053_at   8.905626
# 2     117_at   8.462787
# 3     121_at   9.444058
# 4  1255_g_at   4.657568
# Name:  GSM352126
# Metadata:
#  - title : 11887T (U133plus2): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.832685
# 1    1053_at   8.328337
# 2     117_at   7.685761
# 3     121_at   9.659965
# 4  1255_g_at   4.742302
# Name:  GSM352127
# Metadata:
#  - title : 11993T (U133plus2): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.734945
# 1    1053_at   7.521694
# 2     117_at   7.766366
# 3     121_at   9.791220
# 4  1255_g_at   4.812589
# Name:  GSM352128
# Metadata:
#  - title : 12370T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.428113
# 1    1053_at   9.496469
# 2     117_at   7.350669
# 3     121_at   9.517837
# 4  1255_g_at   4.595701
# Name:  GSM352129
# Metadata:
#  - title : 13685T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.372211
# 1    1053_at   8.218929
# 2     117_at   8.213760
# 3     121_at   9.538818
# 4  1255_g_at   4.582999
# Name:  GSM352130
# Metadata:
#  - title : 14568T (U133plus2): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.359190
# 1    1053_at   8.316559
# 2     117_at   9.066892
# 3     121_at   9.241595
# 4  1255_g_at   4.353619
# Name:  GSM352131
# Metadata:
#  - title : 14891T (U133plus2): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.962973
# 1    1053_at   8.486509
# 2     117_at   9.145501
# 3     121_at   9.429353
# 4  1255_g_at   4.623284
# Name:  GSM352132
# Metadata:
#  - title : 15112T (U133plus2): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.049945
# 1    1053_at   9.248112
# 2     117_at   8.001030
# 3     121_at   9.320542
# 4  1255_g_at   4.745899
# Name:  GSM352133
# Metadata:
#  - title : B22-Met (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.152468
# 1    1053_at   7.137877
# 2     117_at   7.971520
# 3     121_at   9.280934
# 4  1255_g_at   4.838083
# Name:  GSM352134
# Metadata:
#  - title : B34-Met (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.137479
# 1    1053_at   6.986457
# 2     117_at   7.727141
# 3     121_at   9.211982
# 4  1255_g_at   4.921534
# Name:  GSM352135
# Metadata:
#  - title : B35-Met (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.672291
# 1    1053_at   7.023448
# 2     117_at   7.676066
# 3     121_at   9.588508
# 4  1255_g_at   4.907847
# Name:  GSM352136
# Metadata:
#  - title : B41-Met (U133A): Liver metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.924860
# 1    1053_at   7.744287
# 2     117_at   7.928543
# 3     121_at   9.167613
# 4  1255_g_at   4.800135
# Name:  GSM352137
# Metadata:
#  - title : 100184T (U133A): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.226449
# 1    1053_at   6.722765
# 2     117_at   7.876331
# 3     121_at   9.039859
# 4  1255_g_at   4.966327
# Name:  GSM352138
# Metadata:
#  - title : 101258T (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.240711
# 1    1053_at   6.946560
# 2     117_at   7.695262
# 3     121_at   9.231827
# 4  1255_g_at   6.667909
# Name:  GSM352139
# Metadata:
#  - title : 101815T (U133A): Liver metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.304105
# 1    1053_at   6.898267
# 2     117_at   7.817684
# 3     121_at   9.212824
# 4  1255_g_at   4.873014
# Name:  GSM352140
# Metadata:
#  - title : 102962T (U133A): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.262240
# 1    1053_at   7.522768
# 2     117_at   7.911175
# 3     121_at   9.280665
# 4  1255_g_at   4.925503
# Name:  GSM352141
# Metadata:
#  - title : 103696T (U133A): Lung metastasis
# Table data:
#       ID_REF     VALUE
# 0  1007_s_at  9.970720
# 1    1053_at  6.939015
# 2     117_at  8.191304
# 3     121_at  9.303183
# 4  1255_g_at  5.097402
# Name:  GSM352142
# Metadata:
#  - title : 105188T (U133A): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.077249
# 1    1053_at   7.026201
# 2     117_at   7.842717
# 3     121_at   9.073804
# 4  1255_g_at   4.827365
# Name:  GSM352143
# Metadata:
#  - title : 10519T (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.116392
# 1    1053_at   6.870199
# 2     117_at   7.884985
# 3     121_at   9.373012
# 4  1255_g_at   5.002081
# Name:  GSM352144
# Metadata:
#  - title : 105880T (U133A): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.725835
# 1    1053_at   6.823333
# 2     117_at   7.716647
# 3     121_at   9.297672
# 4  1255_g_at   5.043343
# Name:  GSM352145
# Metadata:
#  - title : 106201T (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.956793
# 1    1053_at   7.273806
# 2     117_at   8.021784
# 3     121_at   9.422986
# 4  1255_g_at   5.164343
# Name:  GSM352146
# Metadata:
#  - title : 106389T (U133A): Liver metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.284573
# 1    1053_at   6.954182
# 2     117_at   7.794022
# 3     121_at   9.356610
# 4  1255_g_at   4.971388
# Name:  GSM352147
# Metadata:
#  - title : 106570T (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.785748
# 1    1053_at   6.999797
# 2     117_at   7.916301
# 3     121_at   9.157478
# 4  1255_g_at   4.988931
# Name:  GSM352148
# Metadata:
#  - title : 107426T (U133A): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  12.095007
# 1    1053_at   7.123564
# 2     117_at   8.095631
# 3     121_at   9.088799
# 4  1255_g_at   4.853201
# Name:  GSM352149
# Metadata:
#  - title : 107482T (U133A): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.477174
# 1    1053_at   6.946415
# 2     117_at   8.101149
# 3     121_at   9.125938
# 4  1255_g_at   4.888087
# Name:  GSM352150
# Metadata:
#  - title : 109506T (U133A): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.413019
# 1    1053_at   7.045458
# 2     117_at   7.940420
# 3     121_at   9.250128
# 4  1255_g_at   5.017226
# Name:  GSM352151
# Metadata:
#  - title : 109594T (U133A): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.191400
# 1    1053_at   6.864229
# 2     117_at   8.020717
# 3     121_at   9.252802
# 4  1255_g_at   4.988498
# Name:  GSM352152
# Metadata:
#  - title : 109714T (U133A): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.556431
# 1    1053_at   7.134068
# 2     117_at   7.956436
# 3     121_at   9.139348
# 4  1255_g_at   4.850342
# Name:  GSM352153
# Metadata:
#  - title : 109734T (U133A): Brain metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.894246
# 1    1053_at   6.844777
# 2     117_at   8.382747
# 3     121_at   9.039891
# 4  1255_g_at   4.943635
# Name:  GSM352154
# Metadata:
#  - title : 11887T (U133A): Bone metastasis
# Table data:
#       ID_REF     VALUE
# 0  1007_s_at  9.980981
# 1    1053_at  6.952603
# 2     117_at  7.691649
# 3     121_at  9.446694
# 4  1255_g_at  4.978014
# Name:  GSM352155
# Metadata:
#  - title : 12367T (U133A): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.641363
# 1    1053_at   7.342011
# 2     117_at  11.581405
# 3     121_at   9.340947
# 4  1255_g_at   4.851692
# Name:  GSM352156
# Metadata:
#  - title : 12740T (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.264253
# 1    1053_at   6.899527
# 2     117_at   7.642867
# 3     121_at   9.266817
# 4  1255_g_at   4.901176
# Name:  GSM352157
# Metadata:
#  - title : 12749T (U133A): Liver metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.419611
# 1    1053_at   7.305644
# 2     117_at   7.975581
# 3     121_at   9.183126
# 4  1255_g_at   4.984153
# Name:  GSM352158
# Metadata:
#  - title : 14045T (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.454154
# 1    1053_at   6.827798
# 2     117_at   7.966423
# 3     121_at   9.157328
# 4  1255_g_at   4.950318
# Name:  GSM352159
# Metadata:
#  - title : 14891T (U133A): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.220281
# 1    1053_at   6.946830
# 2     117_at   8.465121
# 3     121_at   9.332640
# 4  1255_g_at   5.060824
# Name:  GSM352160
# Metadata:
#  - title : 15112T (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.122096
# 1    1053_at   7.232990
# 2     117_at   7.887310
# 3     121_at   9.058436
# 4  1255_g_at   5.025135
# Name:  GSM352161
# Metadata:
#  - title : 1813T (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.665713
# 1    1053_at   6.951289
# 2     117_at   8.854454
# 3     121_at   9.196497
# 4  1255_g_at   4.922888
# Name:  GSM352162
# Metadata:
#  - title : 3032T (U133A): Liver metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.531553
# 1    1053_at   7.023597
# 2     117_at   7.617238
# 3     121_at   9.201497
# 4  1255_g_at   4.965196
# Name:  GSM352163
# Metadata:
#  - title : 3878T (U133A): Bone metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.615657
# 1    1053_at   7.014296
# 2     117_at   7.877476
# 3     121_at   9.318078
# 4  1255_g_at   5.101353
# Name:  GSM352164
# Metadata:
#  - title : 4059T (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.253499
# 1    1053_at   6.999848
# 2     117_at   7.746652
# 3     121_at   8.943775
# 4  1255_g_at   4.862778
# Name:  GSM352165
# Metadata:
#  - title : 5381T (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  11.060955
# 1    1053_at   7.609674
# 2     117_at   7.653508
# 3     121_at   9.081481
# 4  1255_g_at   4.880778
# Name:  GSM352166
# Metadata:
#  - title : 6565T (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.999642
# 1    1053_at   6.644695
# 2     117_at   7.794672
# 3     121_at   9.145070
# 4  1255_g_at   4.906529
# Name:  GSM352167
# Metadata:
#  - title : 6752T (U133A): Bone metastasis
# Table data:
#       ID_REF     VALUE
# 0  1007_s_at  9.523839
# 1    1053_at  6.741417
# 2     117_at  8.241767
# 3     121_at  9.340316
# 4  1255_g_at  4.975271
# Name:  GSM352168
# Metadata:
#  - title : 7130T (U133A): Lung metastasis
# Table data:
#       ID_REF      VALUE
# 0  1007_s_at  10.644172
# 1    1053_at   6.826809
# 2     117_at   8.210786
# 3     121_at   9.089787
# 4  1255_g_at   5.329008
#
# GPL example:
# Name:  GPL96
# Metadata:
#  - title : [HG-U133A] Affymetrix Human Genome U133A Array
#  - geo_accession : GPL96
#  - status : Public on Mar 11 2002
#  - submission_date : Feb 19 2002
#  - last_update_date : Aug 10 2018
#  - technology : in situ oligonucleotide
#  - distribution : commercial
#  - organism : Homo sapiens
#  - taxid : 9606
#  - manufacturer : Affymetrix
#  - manufacture_protocol : see manufacturer's web site, , The U133 set includes 2 arrays with a total of 44928 entries and was indexed 29-Jan-2002., The set includes over 1,000,000 unique oligonucleotide features covering more than 39,000 transcript variants, which in turn represent greater than 33,000 of the best characterized human genes., Sequences were selected from GenBank, dbEST, and RefSeq. Sequence clusters were created from Build 133 of UniGene (April 20, 2001) and refined by analysis and comparison with a number of other publicly available databases including the Washington University EST trace repository and the University of California, Santa Cruz golden-path human genome database (April 2001 release). In addition, ESTs were analyzed for untrimmed low-quality sequence information, correct orientation, false priming, false clustering, alternative splicing and alternative polyadenylation.,
#  - description : Affymetrix submissions are typically submitted to GEO using the GEOarchive method described at http://www.ncbi.nlm.nih.gov/projects/geo/info/geo_affy.html, , June 03, 2009: annotation table updated with netaffx build 28, June 08, 2012: annotation table updated with netaffx build 32, June 24, 2016: annotation table updated with netaffx build 35
#  - web_link : http://www.affymetrix.com/support/technical/byproduct.affx?product=hgu133, http://www.affymetrix.com/analysis/index.affx
#  - contact_name : ,,Affymetrix, Inc.
#  - contact_email : geo@ncbi.nlm.nih.gov, support@affymetrix.com
#  - contact_phone : 888-362-2447
#  - contact_institute : Affymetrix, Inc.
#  - contact_address :
#  - contact_city : Santa Clara
#  - contact_state : CA
#  - contact_zip/postal_code : 95051
#  - contact_country : USA
#  - contact_web_link : http://www.affymetrix.com/index.affx
#  - relation : Alternative to: GPL4557 (Alternative CDF), Alternative to: GPL7566 (Alternative CDF), Alternative to: GPL9021 (Alternative CDF), Alternative to: GPL9741 (Alternative CDF), Alternative to: GPL10553 (Alternative CDF: ncilpg_U133Agb), Alternative to: GPL14663 (Alternative CDF), Alternative to: GPL16212 (Alternative CDF), Alternative to: GPL17027 (Alternative CDF), Alternative to: GPL17662 (alternative CDF), Alternative to: GPL19184 (CDF: v18 ENTREZG)
#  - data_row_count : 22283
# Table data:
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...

# %%
controls = ['GSM352095',
'GSM352097',
'GSM352098',
'GSM352100',
'GSM352101',
'GSM352103',
'GSM352105',
'GSM352107',
'GSM352109',
'GSM352110',
'GSM352111',
'GSM352113',
'GSM352114',
'GSM352115',
'GSM352117',
'GSM352119',
'GSM352120',
'GSM352121',
'GSM352122',
'GSM352123',
'GSM352124',
'GSM352125',
'GSM352126',
'GSM352127',
'GSM352128',
'GSM352129',
'GSM352130',
'GSM352131',
'GSM352132',
'GSM352133',
'GSM352134',
'GSM352135',
'GSM352136',
'GSM352137',
'GSM352138',
'GSM352139',
'GSM352140',
'GSM352141',
'GSM352142',
'GSM352143',
'GSM352144',
'GSM352145',
'GSM352146',
'GSM352147',
'GSM352148',
'GSM352149',
'GSM352150',
'GSM352151',
'GSM352152',
'GSM352153',
'GSM352154',
'GSM352155',
'GSM352156',
'GSM352157',
'GSM352158',
'GSM352159',
'GSM352160',
'GSM352161',
'GSM352162',
'GSM352163',
'GSM352164',
'GSM352165',
'GSM352166',
'GSM352167',
'GSM352168']

# %%
pivoted_control_samples = gse.pivot_samples('VALUE')[controls]
pivoted_control_samples.head(5)
# Out:
# name       GSM352095  GSM352097  GSM352098  GSM352100  GSM352101  GSM352103  \
# ID_REF
# 1007_s_at  11.942972  12.028198  12.359949  11.589025  11.405878  10.658286
# 1053_at     9.124514   9.478611   8.936268   8.035468   9.168375   8.102512
# 117_at      7.832843   8.056224   8.230384  10.979582   7.907716   8.983309
# 121_at      9.293999   9.734242   9.196800   9.359527   9.449023   9.438934
# 1255_g_at   4.545640   4.589639   4.443698   4.633253   4.698722   4.755724
#
# name       GSM352105  GSM352107  GSM352109  GSM352110  ...  GSM352159  \
# ID_REF                                                 ...
# 1007_s_at  10.835002  12.091930  12.085872  12.344569  ...  11.220281
# 1053_at     9.247241   9.189113   8.306166   9.104509  ...   6.946830
# 117_at      9.381022   7.796607   8.537037   7.934914  ...   8.465121
# 121_at      9.383646   9.080720   9.423481   9.555070  ...   9.332640
# 1255_g_at   4.530701   4.644450   4.574697   4.610129  ...   5.060824
#
# name       GSM352160  GSM352161  GSM352162  GSM352163  GSM352164  GSM352165  \
# ID_REF
# 1007_s_at  11.122096  10.665713  11.531553  10.615657  10.253499  11.060955
# 1053_at     7.232990   6.951289   7.023597   7.014296   6.999848   7.609674
# 117_at      7.887310   8.854454   7.617238   7.877476   7.746652   7.653508
# 121_at      9.058436   9.196497   9.201497   9.318078   8.943775   9.081481
# 1255_g_at   5.025135   4.922888   4.965196   5.101353   4.862778   4.880778
#
# name       GSM352166  GSM352167  GSM352168
# ID_REF
# 1007_s_at  10.999642   9.523839  10.644172
# 1053_at     6.644695   6.741417   6.826809
# 117_at      7.794672   8.241767   8.210786
# 121_at      9.145070   9.340316   9.089787
# 1255_g_at   4.906529   4.975271   5.329008
#
# [5 rows x 65 columns]

# %%
import pandas as pd
df= pd.DataFrame(pivoted_control_samples)

# %%
df.isnull().sum()
# Out:
# name
# GSM352095        6
# GSM352097        6
# GSM352098        6
# GSM352100        6
# GSM352101        6
#              ...
# GSM352164    32398
# GSM352165    32398
# GSM352166    32398
# GSM352167    32398
# GSM352168    32398
# Length: 65, dtype: int64

# %%
cols=['GSM352095']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352097']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352098']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352100']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352101']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352103']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352105']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352107']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352109']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352110']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352111']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352113']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352115']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352117']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352119']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352120']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352121']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352122']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352123']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352124']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352125']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352126']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352127']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352128']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352129']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352130']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352131']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352132']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352133']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352134']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352135']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352136']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352137']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352138']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352139']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352140']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352141']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352142']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352143']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352144']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352145']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352146']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352147']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352148']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352149']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352150']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352151']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352152']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352153']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352154']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352155']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352156']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352157']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352158']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352159']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352160']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352161']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352162']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352163']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352164']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352165']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352166']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352167']
df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['GSM352168']
df[cols]=df[cols].fillna(df.mean().iloc[0])

# %%
df.isnull().sum()
# Out:
# name
# GSM352095    0
# GSM352097    0
# GSM352098    0
# GSM352100    0
# GSM352101    0
#             ..
# GSM352164    0
# GSM352165    0
# GSM352166    0
# GSM352167    0
# GSM352168    0
# Length: 65, dtype: int64

# %%
import GEOparse
import pandas as pd
import pylab as pl
import seaborn as sns

# %%
pl.rcParams['figure.figsize'] = (14, 10)
pl.rcParams['ytick.labelsize'] = 12
pl.rcParams['xtick.labelsize'] = 11
pl.rcParams['axes.labelsize'] = 23
pl.rcParams['legend.fontsize'] = 20
sns.set_style('ticks')
c1, c2, c3, c4 = sns.color_palette("Set1", 4)
df.hist()
sns.despine(offset=10, trim=True)

# %%
df = pd.read_csv("MLProject.csv",index_col = 0)

# %%
df
# Out:
#                         GSM352095  GSM352097  GSM352098  GSM352100  GSM352101  \
# ID_REF
# 1007_s_at               11.942972  12.028198  12.359949  11.589025  11.405878
# 1053_at                  9.124514   9.478611   8.936268   8.035468   9.168375
# 117_at                   7.832843   8.056224   8.230384  10.979582   7.907716
# 121_at                   9.293999   9.734242   9.196800   9.359527   9.449023
# 1255_g_at                4.545640   4.589639   4.443698   4.633253   4.698722
# ...                           ...        ...        ...        ...        ...
# AFFX-r2-Hs28SrRNA-3_at   7.167422   7.167422   7.167422   7.167422   7.167422
# AFFX-r2-Hs28SrRNA-5_at   7.167422   7.167422   7.167422   7.167422   7.167422
# AFFX-r2-Hs28SrRNA-M_at   7.167422   7.167422   7.167422   7.167422   7.167422
# AFFX-r2-P1-cre-3_at     13.761771  14.173357  14.213187  13.966082  14.098767
# AFFX-r2-P1-cre-5_at     13.626195  13.999518  14.064820  13.751962  13.838414
#
#                         GSM352103  GSM352105  GSM352105.1  GSM352107  \
# ID_REF
# 1007_s_at               10.658286  10.835002    10.835002  12.091930
# 1053_at                  8.102512   9.247241     9.247241   9.189113
# 117_at                   8.983309   9.381022     9.381022   7.796607
# 121_at                   9.438934   9.383646     9.383646   9.080720
# 1255_g_at                4.755724   4.530701     4.530701   4.644450
# ...                           ...        ...          ...        ...
# AFFX-r2-Hs28SrRNA-3_at   7.167422   7.167422     7.167422   7.167422
# AFFX-r2-Hs28SrRNA-5_at   7.167422   7.167422     7.167422   7.167422
# AFFX-r2-Hs28SrRNA-M_at   7.167422   7.167422     7.167422   7.167422
# AFFX-r2-P1-cre-3_at     14.212549  14.022483    14.022483  14.092802
# AFFX-r2-P1-cre-5_at     14.009836  13.765890    13.765890  13.899300
#
#                         GSM352109  ...  GSM352159  GSM352160  GSM352161  \
# ID_REF                             ...
# 1007_s_at               12.085872  ...  11.220281  11.122096  10.665713
# 1053_at                  8.306166  ...   6.946830   7.232990   6.951289
# 117_at                   8.537037  ...   8.465121   7.887310   8.854454
# 121_at                   9.423481  ...   9.332640   9.058436   9.196497
# 1255_g_at                4.574697  ...   5.060824   5.025135   4.922888
# ...                           ...  ...        ...        ...        ...
# AFFX-r2-Hs28SrRNA-3_at   7.167422  ...   8.619765   9.458814   8.210674
# AFFX-r2-Hs28SrRNA-5_at   7.167422  ...   5.310254   5.800877   5.431367
# AFFX-r2-Hs28SrRNA-M_at   7.167422  ...   6.478841   7.287388   6.911227
# 63      8.669564  6.207221  5.738179   7.213031  ...             11.365112
# 64      8.623906  6.266271  5.521432   6.016347  ...             11.522543
# 65      9.198012  6.628119  5.662140   8.570620  ...             12.753672
#
# ID_REF  AFFX-r2-Ec-bioD-5_at  AFFX-r2-Hs18SrRNA-3_s_at  \
# 0                  11.681449                  7.167422
# 1                  12.391372                  7.167422
# 2                  12.547635                  7.167422
# 3                  11.959521                  7.167422
# 4                  12.259550                  7.167422
# ..                       ...                       ...
# 61                 11.139901                  7.264237
# 62                 10.546062                  8.119782
# 63                 11.293651                  7.643475
# 64                 11.396987                  8.190377
# 65                 12.903440                  7.787239
#
# ID_REF  AFFX-r2-Hs18SrRNA-5_at  AFFX-r2-Hs18SrRNA-M_x_at  \
# 0                     7.167422                  7.167422
# 1                     7.167422                  7.167422
# 2                     7.167422                  7.167422
# 3                     7.167422                  7.167422
# 4                     7.167422                  7.167422
# ..                         ...                       ...
# 61                    6.680760                  5.566996
# 62                    7.574709                  6.540825
# 63                    6.639836                  5.710132
# 64                    8.210001                  6.651557
# 65                    7.857642                  6.279080
#
# ID_REF  AFFX-r2-Hs28SrRNA-3_at  AFFX-r2-Hs28SrRNA-5_at  \
# 0                     7.167422                7.167422
# 1                     7.167422                7.167422
# 2                     7.167422                7.167422
# 3                     7.167422                7.167422
# 4                     7.167422                7.167422
# ..                         ...                     ...
# 61                    8.183792                5.300027
# 62                    9.115837                5.365604
# 63                    7.022862                5.190738
# 64                    8.961096                5.682180
# 65                    9.292362                5.865139
#
# ID_REF  AFFX-r2-Hs28SrRNA-M_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at
# 0                     7.167422            13.761771            13.626195
# 1                     7.167422            14.173357            13.999518
# 2                     7.167422            14.213187            14.064820
# 3                     7.167422            13.966082            13.751962
# 4                     7.167422            14.098767            13.838414
# ..                         ...                  ...                  ...
# 61                    6.422075            12.896722            12.677434
# 62                    7.347967            12.744409            12.748299
# 63                    6.443151            13.289318            13.326638
# 64                    6.652361            13.437831            13.372679
# 65                    7.179321            13.903414            13.804293
#
# [66 rows x 54682 columns]

# %%
df.head(5)
# Out:
# ID_REF      index  1007_s_at   1053_at     117_at    121_at  1255_g_at  \
# 0       GSM352095  11.942972  9.124514   7.832843  9.293999   4.545640
# 1       GSM352097  12.028198  9.478611   8.056224  9.734242   4.589639
# 2       GSM352098  12.359949  8.936268   8.230384  9.196800   4.443698
# 3       GSM352100  11.589025  8.035468  10.979582  9.359527   4.633253
# 4       GSM352101  11.405878  9.168375   7.907716  9.449023   4.698722
#
# ID_REF   1294_at   1316_at   1320_at  1405_i_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0       7.871945  6.762140  5.872532   7.875702  ...             12.215268
# 1       8.008909  6.868611  5.940234   7.202162  ...             12.794652
# 2       8.337189  6.834461  5.671500   8.024927  ...             12.884326
# 3       8.527015  7.062760  6.015733   7.383561  ...             12.362589
# 4       7.976891  7.905617  5.884391   5.839641  ...             12.569956
#
# ID_REF  AFFX-r2-Ec-bioD-5_at  AFFX-r2-Hs18SrRNA-3_s_at  \
# 0                  11.681449                  7.167422
# 1                  12.391372                  7.167422
# 2                  12.547635                  7.167422
# 3                  11.959521                  7.167422
# 4                  12.259550                  7.167422
#
# ID_REF  AFFX-r2-Hs18SrRNA-5_at  AFFX-r2-Hs18SrRNA-M_x_at  \
# 0                     7.167422                  7.167422
# 1                     7.167422                  7.167422
# 2                     7.167422                  7.167422
# 3                     7.167422                  7.167422
# 4                     7.167422                  7.167422
#
# ID_REF  AFFX-r2-Hs28SrRNA-3_at  AFFX-r2-Hs28SrRNA-5_at  \
# 0                     7.167422                7.167422
# 1                     7.167422                7.167422
# 2                     7.167422                7.167422
# 3                     7.167422                7.167422
# 4                     7.167422                7.167422
#
# ID_REF  AFFX-r2-Hs28SrRNA-M_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at
# 0                     7.167422            13.761771            13.626195
# 1                     7.167422            14.173357            13.999518
# 2                     7.167422            14.213187            14.064820
# 3                     7.167422            13.966082            13.751962
# 4                     7.167422            14.098767            13.838414
#
# [5 rows x 54682 columns]

# %%
#Genotype-phenotype studies are done for predicting traits i.e. a particular disease given their only genome
gse.phenotype_data.head(5)
# Out:
#                                            title geo_accession  \
# GSM352095     5381T (U133plus2): Lung metastasis     GSM352095
# GSM352097  102962T (U133plus2): Brain metastasis     GSM352097
# GSM352098  104406T (U133plus2): Brain metastasis     GSM352098
# GSM352100   105079T (U133plus2): Bone metastasis     GSM352100
# GSM352101  107502T (U133plus2): Brain metastasis     GSM352101
#
#                           status submission_date last_update_date type  \
# GSM352095  Public on May 01 2009     Dec 17 2008      Aug 28 2018  RNA
# GSM352097  Public on May 01 2009     Dec 17 2008      Aug 28 2018  RNA
# GSM352098  Public on May 01 2009     Dec 17 2008      Aug 28 2018  RNA
# GSM352100  Public on May 01 2009     Dec 17 2008      Aug 28 2018  RNA
# GSM352101  Public on May 01 2009     Dec 17 2008      Aug 28 2018  RNA
#
#           channel_count source_name_ch1  organism_ch1 taxid_ch1  ...  \
# GSM352095             1            Lung  Homo sapiens      9606  ...
# GSM352097             1           Brain  Homo sapiens      9606  ...
# GSM352098             1           Brain  Homo sapiens      9606  ...
# GSM352100             1            Bone  Homo sapiens      9606  ...
# GSM352101             1           Brain  Homo sapiens      9606  ...
#
#                     contact_institute           contact_address contact_city  \
# GSM352095  Baylor College of Medicine  One Baylor Plaza, BCM600      Houston
# GSM352097  Baylor College of Medicine  One Baylor Plaza, BCM600      Houston
# GSM352098  Baylor College of Medicine  One Baylor Plaza, BCM600      Houston
# GSM352100  Baylor College of Medicine  One Baylor Plaza, BCM600      Houston
# GSM352101  Baylor College of Medicine  One Baylor Plaza, BCM600      Houston
#
#           contact_state contact_zip/postal_code contact_country  \
# GSM352095            TX                   77030             USA
# GSM352097            TX                   77030             USA
# GSM352098            TX                   77030             USA
# GSM352100            TX                   77030             USA
# GSM352101            TX                   77030             USA
#
#                                           supplementary_file  \
# GSM352095  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM352n...
# GSM352097  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM352n...
# GSM352098  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM352n...
# GSM352100  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM352n...
# GSM352101  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM352n...
#
#                            relation          series_id data_row_count
# GSM352095  Reanalyzed by: GSE119087  GSE14017,GSE14020          54675
# GSM352097  Reanalyzed by: GSE119087  GSE14017,GSE14020          54675
# GSM352098  Reanalyzed by: GSE119087  GSE14017,GSE14020          54675
# GSM352100  Reanalyzed by: GSE119087  GSE14017,GSE14020          54675
# GSM352101  Reanalyzed by: GSE119087  GSE14017,GSE14020          54675
#
# [5 rows x 34 columns]

# %%
samples = gse.phenotype_data[['geo_accession','source_name_ch1']]
samples
# Out:
#           geo_accession source_name_ch1
# GSM352095     GSM352095            Lung
# GSM352097     GSM352097           Brain
# GSM352098     GSM352098           Brain
# GSM352100     GSM352100            Bone
# GSM352101     GSM352101           Brain
# ...                 ...             ...
# GSM352164     GSM352164            Lung
# GSM352165     GSM352165            Lung
# GSM352166     GSM352166            Lung
# GSM352167     GSM352167            Bone
# GSM352168     GSM352168            Lung
#
# [65 rows x 2 columns]

# %%
#add metastatsis colum corresponding to relevant GSMs
df['Metastasis'] = samples['source_name_ch1']

for i in range(len(df)): 
    if df['index'][i] == 'GSM352095': 
        df['Metastasis'][i]="Lung"
  
    elif df['index'][i] == 'GSM352097': 
        df['Metastasis'][i]="Brain"
  
    elif df['index'][i] == 'GSM352098': 
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352100':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352101':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352103':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352105':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352107':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352109':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352110':
        df['Metastasis'][i]="Brain"
    
    elif df['index'][i] == 'GSM352111':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352113':
        df['Metastasis'][i]="Brain"
    
    elif df['index'][i] == 'GSM352114':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352115':
        df['Metastasis'][i]="Brain"
    
    elif df['index'][i] == 'GSM352117':
        df['Metastasis'][i]="Bone"    
        
    elif df['index'][i] == 'GSM352119':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352120':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352121':
        df['Metastasis'][i]="Brain"  
        
    elif df['index'][i] == 'GSM352122':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352123':
        df['Metastasis'][i]="Bone"   
        
    elif df['index'][i] == 'GSM352124':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352125':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352126':
        df['Metastasis'][i]="Bone"
     
    elif df['index'][i] == 'GSM352127':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352128':
        df['Metastasis'][i]="Brain"  
        
    elif df['index'][i] == 'GSM352129':
        df['Metastasis'][i]="Brain"    
        
    elif df['index'][i] == 'GSM352130':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352131':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352132':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352133':
        df['Metastasis'][i]="Lung"    
        
    elif df['index'][i] == 'GSM352134':
        df['Metastasis'][i]="Lung"   
            
    elif df['index'][i] == 'GSM352135':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352136':
        df['Metastasis'][i]="Liver"
        
    elif df['index'][i] == 'GSM352137':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352138':
        df['Metastasis'][i]="Lung"    
        
    elif df['index'][i] == 'GSM352139':
        df['Metastasis'][i]="Liver"    
        
    elif df['index'][i] == 'GSM352140':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352141':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352142':
        df['Metastasis'][i]="Brain"    
        
    elif df['index'][i] == 'GSM352143':
        df['Metastasis'][i]="Lung"  
        
    elif df['index'][i] == 'GSM352144':
        df['Metastasis'][i]="Bone"    
        
    elif df['index'][i] == 'GSM352145':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352146':
        df['Metastasis'][i]="Liver"
        
    elif df['index'][i] == 'GSM352147':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352148':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352149':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352150':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352151':
        df['Metastasis'][i]="Bone"    
        
    elif df['index'][i] == 'GSM352152':
        df['Metastasis'][i]="Brain"
        
    elif df['index'][i] == 'GSM352153':
        df['Metastasis'][i]="Brain"   
        
    elif df['index'][i] == 'GSM352154':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352155':
        df['Metastasis'][i]="Bone"    
        
    elif df['index'][i] == 'GSM352156':
        df['Metastasis'][i]="Lung"    
        
    elif df['index'][i] == 'GSM352157':
        df['Metastasis'][i]="Liver"   
        
    elif df['index'][i] == 'GSM352158':
        df['Metastasis'][i]="Lung"
        
        
    elif df['index'][i] == 'GSM352159':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352160':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352161':
        df['Metastasis'][i]="Lung"
        
    elif df['index'][i] == 'GSM352162':
        df['Metastasis'][i]="Liver"
        
    elif df['index'][i] == 'GSM352163':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352164':
        df['Metastasis'][i]="Lung"     
        
    elif df['index'][i] == 'GSM352165':
        df['Metastasis'][i]="Lung"   
        
    elif df['index'][i] == 'GSM352166':
        df['Metastasis'][i]="Lung"   
        
    elif df['index'][i] == 'GSM352167':
        df['Metastasis'][i]="Bone"
        
    elif df['index'][i] == 'GSM352168':
        df['Metastasis'][i]="Lung"
# Out:
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:172: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:175: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\KOMAL\Anaconda3\lib\site-packages\ipykernel_launcher.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head(5)
# Out:
# ID_REF      index  1007_s_at   1053_at     117_at    121_at  1255_g_at  \
# 0       GSM352095  11.942972  9.124514   7.832843  9.293999   4.545640
# 1       GSM352097  12.028198  9.478611   8.056224  9.734242   4.589639
# 2       GSM352098  12.359949  8.936268   8.230384  9.196800   4.443698
# 3       GSM352100  11.589025  8.035468  10.979582  9.359527   4.633253
# 4       GSM352101  11.405878  9.168375   7.907716  9.449023   4.698722
#
# ID_REF   1294_at   1316_at   1320_at  1405_i_at  ...  AFFX-r2-Ec-bioD-5_at  \
# 0       7.871945  6.762140  5.872532   7.875702  ...             11.681449
# 1       8.008909  6.868611  5.940234   7.202162  ...             12.391372
# 2       8.337189  6.834461  5.671500   8.024927  ...             12.547635
# 3       8.527015  7.062760  6.015733   7.383561  ...             11.959521
# 4       7.976891  7.905617  5.884391   5.839641  ...             12.259550
#
# ID_REF  AFFX-r2-Hs18SrRNA-3_s_at  AFFX-r2-Hs18SrRNA-5_at  \
# 0                       7.167422                7.167422
# 1                       7.167422                7.167422
# 2                       7.167422                7.167422
# 3                       7.167422                7.167422
# 4                       7.167422                7.167422
#
# ID_REF  AFFX-r2-Hs18SrRNA-M_x_at  AFFX-r2-Hs28SrRNA-3_at  \
# 0                       7.167422                7.167422
# 1                       7.167422                7.167422
# 2                       7.167422                7.167422
# 3                       7.167422                7.167422
# 4                       7.167422                7.167422
#
# ID_REF  AFFX-r2-Hs28SrRNA-5_at  AFFX-r2-Hs28SrRNA-M_at  AFFX-r2-P1-cre-3_at  \
# 0                     7.167422                7.167422            13.761771
# 1                     7.167422                7.167422            14.173357
# 2                     7.167422                7.167422            14.213187
# 3                     7.167422                7.167422            13.966082
# 4                     7.167422                7.167422            14.098767
#
# ID_REF  AFFX-r2-P1-cre-5_at  Metastasis
# 0                 13.626195        Lung
# 1                 13.999518       Brain
# 2                 14.064820       Brain
# 3                 13.751962        Bone
# 4                 13.838414       Brain
#
# [5 rows x 54683 columns]

# %%
df.isnull().sum()
# Out:
# ID_REF
# index                     0
# 1007_s_at                 0
# 1053_at                   0
# 117_at                    0
# 121_at                    0
#                          ..
# AFFX-r2-Hs28SrRNA-5_at    0
# AFFX-r2-Hs28SrRNA-M_at    0
# AFFX-r2-P1-cre-3_at       0
# AFFX-r2-P1-cre-5_at       0
# Metastasis                1
# Length: 54683, dtype: int64

# %%
#cols=['AFFX-r2-Hs28SrRNA-5_at']
#df[cols]=df[cols].fillna(df.mean().iloc[0])

#cols=['AFFX-r2-Hs28SrRNA-M_at']
#df[cols]=df[cols].fillna(df.mean().iloc[0])

cols=['Metastasis']
df[cols]=df[cols].fillna(df.mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# ID_REF
# index                     0
# 1007_s_at                 0
# 1053_at                   0
# 117_at                    0
# 121_at                    0
#                          ..
# AFFX-r2-Hs28SrRNA-5_at    0
# AFFX-r2-Hs28SrRNA-M_at    0
# AFFX-r2-P1-cre-3_at       0
# AFFX-r2-P1-cre-5_at       0
# Metastasis                0
# Length: 54683, dtype: int64

# %%
data = df.drop(columns=['index'])
df1 = data.dropna()
df1
# Out:
# ID_REF  1007_s_at   1053_at     117_at    121_at  1255_g_at   1294_at  \
# 0       11.942972  9.124514   7.832843  9.293999   4.545640  7.871945
# 1       12.028198  9.478611   8.056224  9.734242   4.589639  8.008909
# 2       12.359949  8.936268   8.230384  9.196800   4.443698  8.337189
# 3       11.589025  8.035468  10.979582  9.359527   4.633253  8.527015
# 4       11.405878  9.168375   7.907716  9.449023   4.698722  7.976891
# ..            ...       ...        ...       ...        ...       ...
# 61      10.253499  6.999848   7.746652  8.943775   4.862778  8.790295
# 62      11.060955  7.609674   7.653508  9.081481   4.880778  7.839485
# 63      10.999642  6.644695   7.794672  9.145070   4.906529  8.669564
# 64       9.523839  6.741417   8.241767  9.340316   4.975271  8.623906
# 65      10.644172  6.826809   8.210786  9.089787   5.329008  9.198012
#
# ID_REF   1316_at   1320_at  1405_i_at   1431_at  ...  AFFX-r2-Ec-bioD-5_at  \
# 0       6.762140  5.872532   7.875702  5.573558  ...             11.681449
# 1       6.868611  5.940234   7.202162  8.231460  ...             12.391372
# 2       6.834461  5.671500   8.024927  5.774710  ...             12.547635
# 3       7.062760  6.015733   7.383561  5.816399  ...             11.959521
# 4       7.905617  5.884391   5.839641  5.397932  ...             12.259550
# ..           ...       ...        ...       ...  ...                   ...
# 61      6.004743  5.837794   7.065387  5.169783  ...             11.139901
# 62      6.160537  5.569111   6.315537  4.753061  ...             10.546062
# 63      6.207221  5.738179   7.213031  4.891167  ...             11.293651
# 64      6.266271  5.521432   6.016347  5.127959  ...             11.396987
# 65      6.628119  5.662140   8.570620  4.958050  ...             12.903440
#
# ID_REF  AFFX-r2-Hs18SrRNA-3_s_at  AFFX-r2-Hs18SrRNA-5_at  \
# 0                       7.167422                7.167422
# 1                       7.167422                7.167422
# 2                       7.167422                7.167422
# 3                       7.167422                7.167422
# 4                       7.167422                7.167422
# ..                           ...                     ...
# 61                      7.264237                6.680760
# 62                      8.119782                7.574709
# 63                      7.643475                6.639836
# 64                      8.190377                8.210001
# 65                      7.787239                7.857642
#
# ID_REF  AFFX-r2-Hs18SrRNA-M_x_at  AFFX-r2-Hs28SrRNA-3_at  \
# 0                       7.167422                7.167422
# 1                       7.167422                7.167422
# 2                       7.167422                7.167422
# 3                       7.167422                7.167422
# 4                       7.167422                7.167422
# ..                           ...                     ...
# 61                      5.566996                8.183792
# 62                      6.540825                9.115837
# 63                      5.710132                7.022862
# 64                      6.651557                8.961096
# 65                      6.279080                9.292362
#
# ID_REF  AFFX-r2-Hs28SrRNA-5_at  AFFX-r2-Hs28SrRNA-M_at  AFFX-r2-P1-cre-3_at  \
# 0                     7.167422                7.167422            13.761771
# 1                     7.167422                7.167422            14.173357
# 2                     7.167422                7.167422            14.213187
# 3                     7.167422                7.167422            13.966082
# 4                     7.167422                7.167422            14.098767
# ..                         ...                     ...                  ...
# 61                    5.300027                6.422075            12.896722
# 62                    5.365604                7.347967            12.744409
# 63                    5.190738                6.443151            13.289318
# 64                    5.682180                6.652361            13.437831
# 65                    5.865139                7.179321            13.903414
#
# ID_REF  AFFX-r2-P1-cre-5_at  Metastasis
# 0                 13.626195        Lung
# 1                 13.999518       Brain
# 2                 14.064820       Brain
# 3                 13.751962        Bone
# 4                 13.838414       Brain
# ..                      ...         ...
# 61                12.677434        Lung
# 62                12.748299        Lung
# 63                13.326638        Lung
# 64                13.372679        Bone
# 65                13.804293        Lung
#
# [66 rows x 54682 columns]

# %%
#defining x and y and removing metastasis from data frame as i'm going to predict metastasis 
import numpy as np
x=df1
y=df1['Metastasis']
del x['Metastasis']

# %%
#Applying feature Scalling in order to normalize the data and speed up the calculations in an algorithm.
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x1 = sc.fit_transform(x)

# %%
categorical_feature_columns = list(set(df.columns) - set(df._get_numeric_data().columns))
categorical_feature_columns
# Out:
# ['index', 'Metastasis']

# %%
numerical_feature_columns = list(df._get_numeric_data().columns)
numerical_feature_columns
# Out:
# ['1007_s_at',
#  '1053_at',
#  '117_at',
#  '121_at',
#  '1255_g_at',
#  '1294_at',
#  '1316_at',
#  '1320_at',
#  '1405_i_at',
#  '1431_at',
#  '1438_at',
#  '1487_at',
#  '1494_f_at',
#  '1552256_a_at',
#  '1552257_a_at',
#  '1552258_at',
#  '1552261_at',
#  '1552263_at',
#  '1552264_a_at',
#  '1552266_at',
#  '1552269_at',
#  '1552271_at',
#  '1552272_a_at',
#  '1552274_at',
#  '1552275_s_at',
#  '1552276_a_at',
#  '1552277_a_at',
#  '1552278_a_at',
#  '1552279_a_at',
#  '1552280_at',
#  '1552281_at',
#  '1552283_s_at',
#  '1552286_at',
#  '1552287_s_at',
#  '1552288_at',
#  '1552289_a_at',
#  '1552291_at',
#  '1552293_at',
#  '1552295_a_at',
#  '1552296_at',
#  '1552299_at',
#  '1552301_a_at',
#  '1552302_at',
#  '1552303_a_at',
#  '1552304_at',
#  '1552306_at',
#  '1552307_a_at',
#  '1552309_a_at',
#  '1552310_at',
#  '1552311_a_at',
#  '1552312_a_at',
#  '1552314_a_at',
#  '1552315_at',
#  '1552316_a_at',
#  '1552318_at',
#  '1552319_a_at',
#  '1552320_a_at',
#  '1552321_a_at',
#  '1552322_at',
#  '1552323_s_at',
#  '1552325_at',
#  '1552326_a_at',
#  '1552327_at',
#  '1552329_at',
#  '1553521_at',
#  '1553523_at',
#  '1553524_at',
#  '1553525_at',
#  '1553526_at',
#  '1553527_at',
#  '1553528_a_at',
#  '1553529_at',
#  '1553530_a_at',
#  '1553531_at',
#  '1553532_a_at',
#  '1553533_at',
#  '1553534_at',
#  '1553535_a_at',
#  '1553536_at',
#  '1553537_at',
#  '1553538_s_at',
#  '1553539_at',
#  '1553540_a_at',
#  '1553541_at',
#  '1553542_at',
#  '1553544_at',
#  '1553545_at',
#  '1553546_at',
#  '1553547_at',
#  '1553549_at',
#  '1553550_at',
#  '1553551_s_at',
#  '1553552_at',
#  '1553553_at',
#  '1553555_at',
#  '1553556_at',
#  '1553558_at',
#  '1553559_at',
#  '1553560_at',
#  '1553561_at',
#  '1553562_at',
#  '1553564_at',
#  '1553565_s_at',
#  '1553566_at',
#  '1553567_s_at',
#  '1553568_a_at',
#  '1553569_at',
#  '1553570_x_at',
#  '1553572_a_at',
#  '1553573_s_at',
#  '1553574_at',
#  '1553575_at',
#  '1553579_a_at',
#  '1553581_s_at',
#  '1553582_a_at',
#  '1553583_a_at',
#  '1553584_at',
#  '1553585_a_at',
#  '1553586_at',
#  '1553587_a_at',
#  '1553588_at',
#  '1553589_a_at',
#  '1553590_at',
#  '1553591_at',
#  '1553592_x_at',
#  '1553593_a_at',
#  '1553594_a_at',
#  '1553599_a_at',
#  '1553600_at',
#  '1553601_a_at',
#  '1553602_at',
#  '1553603_s_at',
#  '1553604_at',
#  '1553605_a_at',
#  '1553607_at',
#  '1553608_a_at',
#  '1553611_s_at',
#  '1553612_at',
#  '1553613_s_at',
#  '1553614_a_at',
#  '1553618_at',
#  '1553619_a_at',
#  '1553620_at',
#  '1553622_a_at',
#  '1553623_at',
#  ...]

# %%
x.shape
# Out:
# (66, 54681)

# %%
y.shape
# Out:
# (66,)

# %%
#Feature Selection
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# %%
select_feature = SelectKBest(chi2, k=20).fit(x,y)

# %%
selected_features_df = pd.DataFrame({'Feature' : list(x.columns),
                                    'Scores' : select_feature.scores_})
selected_features_df.sort_values(by = 'Scores', ascending = False)
# Out:
#            Feature     Scores
# 54258     37004_at  34.803691
# 15355  205908_s_at  33.334935
# 28119    218835_at  32.242999
# 26713  217428_s_at  28.894758
# 15160  205713_s_at  28.611773
# ...            ...        ...
# 42122    232869_at   0.000093
# 49263    240014_at   0.000092
# 26661    217376_at   0.000088
# 47384    238135_at   0.000074
# 26528    217242_at   0.000056
#
# [54681 rows x 2 columns]

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt

model = ExtraTreesClassifier()
model.fit(x,y)
# Out:
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#                      max_depth=None, max_features='auto', max_leaf_nodes=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#                      oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
print (model.feature_importances_)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
feat_importances = pd.Series(model.feature_importances_, index = x.columns)
plt.figure(figsize = (12,8))
feat_importances.nlargest(20).plot(kind = 'barh')
plt.show()

# %%
feature_list = list(feat_importances.nlargest(20).to_frame().index)
feature_list
# Out:
# ['1556717_at',
#  '215816_at',
#  '204510_at',
#  '240608_at',
#  '211896_s_at',
#  '230411_at',
#  '235064_s_at',
#  '209047_at',
#  '213502_x_at',
#  '222348_at',
#  '205713_s_at',
#  '205117_at',
#  '202828_s_at',
#  '211645_x_at',
#  '209894_at',
#  '223967_at',
#  '216380_x_at',
#  '207173_x_at',
#  '203632_s_at',
#  '220350_at']

# %%
x = x[feature_list]
x
# Out:
# ID_REF  1556717_at  215816_at  204510_at  240608_at  211896_s_at  230411_at  \
# 0         7.133939   6.956679   8.369127   6.460664    10.420777   6.963616
# 1         7.697555   7.148847   9.280879   6.057757    11.823261   7.587602
# 2         7.327196   7.007365   9.066993   6.068341     9.261653   7.145870
# 3         7.018072   6.933431   6.701630   6.537055    13.543239   7.559365
# 4         7.463163   7.105039   8.415473   6.886609     9.410386   7.763978
# ..             ...        ...        ...        ...          ...        ...
# 61        7.167422   7.077993   6.505424   7.167422    10.454128   7.167422
# 62        7.167422   7.136868   7.476546   7.167422     9.222382   7.167422
# 63        7.167422   7.180486   6.253667   7.167422    11.705861   7.167422
# 64        7.167422   7.346397   6.817466   7.167422    11.177092   7.167422
# 65        7.167422   7.291004   6.723674   7.167422     8.595848   7.167422
#
# ID_REF  235064_s_at  209047_at  213502_x_at  222348_at  205713_s_at  \
# 0          7.441848   8.538279    12.318282   5.278626     7.048587
# 1          7.935077   8.162130    11.133943   6.794535     5.982185
# 2          7.744951   7.934189    11.216575   6.743269     9.199631
# 3          7.346520  11.943064     9.906310   7.444557    14.055305
# 4          7.760382   7.544961     9.722232   8.300017     8.040090
# ..              ...        ...          ...        ...          ...
# 61         7.167422   8.795094     9.135815   6.216538     5.738162
# 62         7.167422   7.969359    11.046628   5.146650     6.127733
# 63         7.167422  10.510587     9.722905   5.562100     5.756635
# 64         7.167422   9.756625     8.539453   5.681952    10.814242
# 65         7.167422  10.084438    10.509217   5.900809     7.278804
#
# ID_REF  205117_at  202828_s_at  211645_x_at  209894_at  223967_at  \
# 0        8.029590     8.598493    12.170251   6.060196   6.939435
# 1        7.953600     7.863715     8.495792   7.177220   6.633205
# 2        9.610295     8.520602     8.813137   5.935669   6.716785
# 3        9.408051     9.037099     7.449436  12.037914   6.830483
# 4        8.881106     8.338454     8.148093   7.538223   6.555909
# ..            ...          ...          ...        ...        ...
# 61       7.628755     8.022859     8.161267   5.776690   7.167422
# 62       7.673597     7.835006    12.332243   4.584410   7.167422
# 63       7.916527     7.958403     9.599961   8.192697   7.167422
# 64       8.397404     8.681210     7.164470   6.134281   7.167422
# 65       8.337634     8.325254     8.638130   5.501173   7.167422
#
# ID_REF  216380_x_at  207173_x_at  203632_s_at  220350_at
# 0         11.776273     9.165218    10.474106   7.122568
# 1         10.141613     9.691046     7.383468   7.363998
# 2          9.573124     8.901806     9.706158   7.137727
# 3         10.151857    12.896151     7.408316   7.118903
# 4         10.079092     8.880417     6.918340   7.409806
# ..              ...          ...          ...        ...
# 61        10.599672    10.888879     9.890705   5.746983
# 62        11.054012     7.738089    10.020410   5.891886
# 63         9.999454     9.320435     7.919088   5.745275
# 64         9.737197    11.081843     8.571165   5.809691
# 65         9.195332     7.719961     8.179448   5.807263
#
# [66 rows x 20 columns]

# %%
#As the data is now scalled and label encoding is done now lets split out data into train and test
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3 , random_state=0)

# %%
# Fitting XGBClassifier to the training data: Model_1 
from xgboost import XGBClassifier

# %%
classifier_1 = XGBClassifier()
classifier_1.fit(xtrain,ytrain)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
# Fitting SVM to the training data: Model 2
from sklearn.svm import SVC

# %%
#applying the model2 on training dataset
classifier_2 = svc_model  = SVC()

# %%
classifier_2.fit(xtrain, ytrain)
# Out:
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
## Fitting Random Forest Classifier to the training data: Model 3
from sklearn.ensemble import RandomForestClassifier

# %%
classifier_3=RandomForestClassifier(n_estimators = 20)
classifier_3.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#Import knearest neighbors Classifier model4
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=19)

#Train the model using the training sets
knn.fit(xtrain, ytrain)

#Predict the response for test dataset
#ypred_4 = knn.predict(xtest)
#ypred_4
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=19, p=2,
#                      weights='uniform')

# %%
#Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
gnb = GaussianNB()

#Train the model using the training sets
gnb.fit(xtrain, ytrain)

#Predict the response for test dataset
#ypred_6 = gnb.predict(xtest)
#ypred_6
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
from sklearn.model_selection import cross_val_score

from sklearn.model_selection import KFold, cross_val_score
#from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
Kfold = KFold(len(x),shuffle = False)
print("KfoldCrossVal score using XGBoster is %s" %cross_val_score(classifier_1,x,y,cv=10).mean())
# Out:
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:657: Warning: The least populated class in y has only 5 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# KfoldCrossVal score using XGBoster is 0.8157142857142858

# %%
Kfold = KFold(len(x),shuffle = False)
print("KfoldCrossVal score using SVM is %s" %cross_val_score(classifier_2,x,y,cv=10).mean())
# Out:
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:657: Warning: The least populated class in y has only 5 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# KfoldCrossVal score using SVM is 0.8797619047619047

# %%
Kfold = KFold(len(x),shuffle = False)
print("KfoldCrossVal score using Random Forest is %s" %cross_val_score(classifier_3,x,y,cv=10).mean())
# Out:
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:657: Warning: The least populated class in y has only 5 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# KfoldCrossVal score using Random Forest is 0.8123809523809523

# %%
Kfold = KFold(len(x),shuffle = False)
print("KfoldCrossVal score using KNN is %s" %cross_val_score(knn,x,y,cv=10).mean())
# Out:
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:657: Warning: The least populated class in y has only 5 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# KfoldCrossVal score using KNN is 0.8047619047619048

# %%
Kfold = KFold(len(x),shuffle = False)
print("KfoldCrossVal score using Naive Bay's is %s" %cross_val_score(gnb,x,y,cv=10).mean())
# Out:
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:657: Warning: The least populated class in y has only 5 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# KfoldCrossVal score using Naive Bay's is 0.4261904761904762

# %%
#Specificity&Sensitivity

# %%
from sklearn import metrics

# %%
#predicting the test set result for Model1
ypred_1 = classifier_1.predict(xtest)
print (ypred_1)
# Out:
# ['Brain' 'Bone' 'Bone' 'Lung' 'Lung' 'Lung' 'Bone' 'Liver' 'Brain' 'Brain'
#  'Lung' 'Lung' 'Brain' 'Bone' 'Lung' 'Brain' 'Brain' 'Lung' 'Brain'
#  'Brain']

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm1 = confusion_matrix(ytest, ypred_1)
pd.crosstab(ytest, ypred_1, rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted  Bone  Brain  Liver  Lung
# Actual
# Bone          3      0      1     0
# Brain         0      7      0     0
# Liver         0      1      0     0
# Lung          1      0      0     7

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(ytest, ypred_1))
# Out:
# Accuracy: 0.85

# %%
#Model Evaluation
print("Model evaluation XGBooster:\n" + classification_report(ytest,ypred_1))
# Out:
# Model evaluation XGBooster:
#               precision    recall  f1-score   support
#
#         Bone       0.75      0.75      0.75         4
#        Brain       0.88      1.00      0.93         7
#        Liver       0.00      0.00      0.00         1
#         Lung       1.00      0.88      0.93         8
#
#     accuracy                           0.85        20
#    macro avg       0.66      0.66      0.65        20
# weighted avg       0.86      0.85      0.85        20

# %%
#Model2
ypred_2 = classifier_2.predict(xtest)
print (ypred_2)
# Out:
# ['Brain' 'Bone' 'Lung' 'Lung' 'Lung' 'Lung' 'Bone' 'Bone' 'Brain' 'Brain'
#  'Lung' 'Lung' 'Brain' 'Bone' 'Lung' 'Brain' 'Brain' 'Bone' 'Brain'
#  'Brain']

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm2 = confusion_matrix(ytest, ypred_2)
pd.crosstab(ytest, ypred_2, rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted  Bone  Brain  Lung
# Actual
# Bone          4      0     0
# Brain         0      7     0
# Liver         0      1     0
# Lung          1      0     7

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cm2 = confusion_matrix(ytest, ypred_2)
cm2_df = pd.DataFrame(cm2,index = ['Brain','Bone','Liver', 'Lung'], columns = ['Brain','Bone','Liver', 'Lung'])
plt.figure(figsize=(8,6))
sns.heatmap(cm2_df, annot=True)
plt.title('SVM \nHeat Map Representation')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show()

# %%
print(classification_report(ytest, ypred_2))
# Out:
#               precision    recall  f1-score   support
#
#         Bone       0.80      1.00      0.89         4
#        Brain       0.88      1.00      0.93         7
#        Liver       0.00      0.00      0.00         1
#         Lung       1.00      0.88      0.93         8
#
#     accuracy                           0.90        20
#    macro avg       0.67      0.72      0.69        20
# weighted avg       0.87      0.90      0.88        20

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(ytest, ypred_2))
# Out:
# Accuracy: 0.9

# %%
#Model Evaluation
print("Model evaluation of SVM :\n" + classification_report(ytest,ypred_2))
# Out:
# C:\Users\KOMAL\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Model evaluation of SVM :
#               precision    recall  f1-score   support
#
#         Bone       0.80      1.00      0.89         4
#        Brain       0.88      1.00      0.93         7
#        Liver       0.00      0.00      0.00         1
#         Lung       1.00      0.88      0.93         8
#
#     accuracy                           0.90        20
#    macro avg       0.67      0.72      0.69        20
# weighted avg       0.87      0.90      0.88        20

# %%
#Model3
ypred_3= classifier_3.predict(xtest)
print (ypred_3)
# Out:
# ['Brain' 'Bone' 'Bone' 'Lung' 'Lung' 'Lung' 'Bone' 'Liver' 'Brain' 'Brain'
#  'Lung' 'Lung' 'Brain' 'Bone' 'Lung' 'Brain' 'Brain' 'Lung' 'Brain'
#  'Brain']

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm3 = confusion_matrix(ytest, ypred_3)
pd.crosstab(ytest, ypred_3, rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted  Bone  Brain  Liver  Lung
# Actual
# Bone          3      0      1     0
# Brain         0      7      0     0
# Liver         0      1      0     0
# Lung          1      0      0     7

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(ytest, ypred_3))
# Out:
# Accuracy: 0.85

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
#Model Evaluation
print("Model evaluation of Random Forest:\n" + classification_report(ytest,ypred_3))
# Out:
# Model evaluation of Random Forest:
#               precision    recall  f1-score   support
#
#         Bone       0.75      0.75      0.75         4
#        Brain       0.88      1.00      0.93         7
#        Liver       0.00      0.00      0.00         1
#         Lung       1.00      0.88      0.93         8
#
#     accuracy                           0.85        20
#    macro avg       0.66      0.66      0.65        20
# weighted avg       0.86      0.85      0.85        20

# %%
#Model 4
ypred_4 = knn.predict(xtest)
ypred_4
# Out:
# array(['Brain', 'Bone', 'Bone', 'Brain', 'Lung', 'Brain', 'Bone', 'Brain',
#        'Brain', 'Brain', 'Lung', 'Lung', 'Brain', 'Bone', 'Brain',
#        'Brain', 'Brain', 'Lung', 'Brain', 'Brain'], dtype=object)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm4 = confusion_matrix(ytest, ypred_4)
pd.crosstab(ytest, ypred_4, rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted  Bone  Brain  Lung
# Actual
# Bone          3      1     0
# Brain         0      7     0
# Liver         0      1     0
# Lung          1      3     4

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(ytest, ypred_4))
# Out:
# Accuracy: 0.7

# %%
#Model Evaluation
print("Model evaluation of KNN: \n" + classification_report(ytest,ypred_4))
# Out:
# Model evaluation of KNN:
#               precision    recall  f1-score   support
#
#         Bone       0.75      0.75      0.75         4
#        Brain       0.58      1.00      0.74         7
#        Liver       0.00      0.00      0.00         1
#         Lung       1.00      0.50      0.67         8
#
#     accuracy                           0.70        20
#    macro avg       0.58      0.56      0.54        20
# weighted avg       0.75      0.70      0.67        20

# %%
#Model 5
ypred_5 = gnb.predict(xtest)
ypred_5
# Out:
# array(['Liver', 'Bone', 'Bone', 'Liver', 'Lung', 'Liver', 'Bone', 'Lung',
#        'Brain', 'Brain', 'Liver', 'Lung', 'Lung', 'Bone', 'Lung', 'Brain',
#        'Brain', 'Lung', 'Brain', 'Brain'], dtype='<U5')

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm5 = confusion_matrix(ytest, ypred_5)
pd.crosstab(ytest, ypred_5, rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted  Bone  Brain  Liver  Lung
# Actual
# Bone          3      0      0     1
# Brain         0      6      1     0
# Liver         0      0      0     1
# Lung          1      0      3     4

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(ytest, ypred_5))
# Out:
# Accuracy: 0.65

# %%
#Model Evaluation
print("Model evaluation of Naive Bayes: \n" + classification_report(ytest,ypred_5))
# Out:
# Model evaluation of Naive Bayes:
#               precision    recall  f1-score   support
#
#         Bone       0.75      0.75      0.75         4
#        Brain       1.00      0.86      0.92         7
#        Liver       0.00      0.00      0.00         1
#         Lung       0.67      0.50      0.57         8
#
#     accuracy                           0.65        20
#    macro avg       0.60      0.53      0.56        20
# weighted avg       0.77      0.65      0.70        20

# %%
accuracy_1 = metrics.accuracy_score(ytest, ypred_1)
accuracy_2 = metrics.accuracy_score(ytest, ypred_2)
accuracy_3 = metrics.accuracy_score(ytest, ypred_3)
accuracy_4 = metrics.accuracy_score(ytest, ypred_4)
accuracy_6 = metrics.accuracy_score(ytest, ypred_5)
#print("Accuracy XGBoost:",accuracy_1*100,'%',"\nAccuracy Support Vector Macchine:",accuracy_2*100,'%',"\nAccuracy Random Forest:",accuracy_3*100,'%',"\nKNN Classifier:",accuracy_4*100,'%',"\nAccuracy Gaussian Naive Bayes:",accuracy_6*100,'%')

# %%
import pandas as pd
Models_Accuracy = {'Models': ['XGBoost','Support Vector Macchine','Random Forest','KNN Classifier','Gaussian Naive Bayes'],
        'Accuracy': [accuracy_1*100,accuracy_2*100,accuracy_3*100,accuracy_4*100,accuracy_6*100]
        }

df = pd.DataFrame(Models_Accuracy, columns = ['Models', 'Accuracy'])

df
# Out:
#                     Models  Accuracy
# 0                  XGBoost      85.0
# 1  Support Vector Macchine      90.0
# 2            Random Forest      85.0
# 3           KNN Classifier      70.0
# 4     Gaussian Naive Bayes      65.0
